# %%
from api_context.api import ApiManager


def _main():
    api_manager = ApiManager()

    input_currency = input("Please enter the name of a currency. : ")
    input_last_nr_of_days = int(input("Please enter last nr of days. : "))
    api_manager.query_get_x_rate_last_n_days(
        input_currency,
        input_last_nr_of_days,
    )


if __name__ == "__main__":
    _main()

# %%
from api_context.api import ApiManager


def _main():
    api_manager = ApiManager()

    input_currency = input("Please enter the name of a currency. : ")
    input_start_date = str(input("Please enter starting date. : "))
    input_end_date = str(input("Please enter ending date. : "))
    api_manager.query_get_x_rate_range(
        input_currency,
        input_start_date,
        input_end_date,
    )


if __name__ == "__main__":
    _main()
# Out:
# /api/exchangerates/rates/C/Usd/2024-01-01/2024-01-10
# [3.8862, 3.9369, 3.9488, 3.9353, 3.9292, 3.9204, 3.9278]
# [datetime.datetime(2024, 1, 2, 0, 0), datetime.datetime(2024, 1, 3, 0, 0), datetime.datetime(2024, 1, 4, 0, 0), datetime.datetime(2024, 1, 5, 0, 0), datetime.datetime(2024, 1, 8, 0, 0), datetime.datetime(2024, 1, 9, 0, 0), datetime.datetime(2024, 1, 10, 0, 0)]
